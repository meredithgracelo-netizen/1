# %%
import requests
import time
import matplotlib.pyplot as plt

# %%
latitudes = []
longitudes = []
timestamps = []

# %%
for i in range(100):
    response = requests.get("http://api.open-notify.org/iss-now.json")
    data = response.json()
    
    latitude = float(data["iss_position"]["latitude"])
    longitude = float(data["iss_position"]["longitude"])
    ts = data["timestamp"]
    
    latitudes.append(latitude)
    longitudes.append(longitude)
    timestamps.append(ts)

# %%
print(f"Point {i+1:03d}: Latitude = {latitude:.5f}, Longitude = {longitude:.5f}, Time = {ts}")
# Out:
# Point 100: Latitude = -11.71090, Longitude = 20.58410, Time = 1758111063

# %%
time.sleep(10)

# %%
plt.figure(figsize=(10, 5))
plt.plot(longitudes, latitudes, marker='o', markersize=3, linestyle='-')
plt.title("International Space Station Path")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.show()
